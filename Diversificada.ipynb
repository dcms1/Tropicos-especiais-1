# %% [markdown]
# <a href="https://colab.research.google.com/github/dcms1/Tropicos-especiais-1/blob/main/Diversificada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importando as Bibliotecas

# %%
pip install pytesseract

# %%
! sudo apt install tesseract-ocr

# %%
import numpy as np
import pandas as pd
import cv2 as cv2
from google.colab.patches import cv2_imshow 
from skimage import io
from PIL import Image 
import matplotlib.pylab as plt
import scipy
import pytesseract
import dlib

# %% [markdown]
# # Pegando a imagem, tranformando em cinza e unindo-as

# %% [markdown]
# 1)Desenvolva um código que lhe permita abrir uma imagem RGB ou BGR de sua preferência, utilizando a interface python do OpenCV. Logo depois, converta a imagem para escala de cinza e exiba as duas imagens lado a lado na tela. Documente as funções utilizadas no código.

# %%
image = cv2.imread('sorrir.jpg')#lendo a imagem
image_2 = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)#tranformando a imagem para a escala de cinza
#imagem_final = cv2.hconcat([image, image_2])
#cv2_imshow(imagem_final)
cv2_imshow(image)
cv2_imshow(image_2)
# Out:
# <PIL.Image.Image image mode=RGB size=900x431 at 0x7F02B18F4B10>
# <PIL.Image.Image image mode=L size=900x431 at 0x7F02B1FB9550>

# %% [markdown]
# # Questao 2 - Reconhecendo as faces

# %% [markdown]
# 2) Utilizando o código fonte das nossas aulas como base, carregue uma imagem contendo pelo menos uma face (pode ser a imagem carregada no item 1), depois carregue o modelo de detecção de faces utilizado nas nossas aulas anteriores. Construa um código de detecção de faces, encontre a caixa envolvente da face na imagem. Pinte o retângulo ao redor da(s) face(s) encontrada(s) e exiba a imagem pintada na tela. Documente as funções utilizadas no código.

# %%
# Rede pre treinada
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

#Executa a detecção das faces:
faces = face_cascade.detectMultiScale(image_2, scaleFactor = 1.10, minNeighbors = 9, minSize = (30,30), flags = cv2.CASCADE_SCALE_IMAGE)

# Desenha retangulos na iamgem original (colorida) para cada face encontrada:
for (x,y,w,h) in faces:
     cv2.rectangle(image_2,(x,y),(x+w,y+h),(255,0,0),2)

cv2_imshow(image_2)
# Out:
# <PIL.Image.Image image mode=RGB size=900x431 at 0x7F0280D9B210>

# %%
final_frame = cv2.hconcat([gray_image,image]) 
  cv2_imshow(final_frame)

# %% [markdown]
# # Questao 3 - Tesseract

# %%
image = io.imread("/content/Imagem texto.png")

# %%
text = pytesseract.image_to_string(image, lang = 'eng')

# %%
text
# Out:
# 'Overview\n\nThe Astronomer Certification: Apache Airflow DAG Authoring\nPreparation Course is an on-demand class which dives into the topics\ncovered on the Astronomer Certification: Apache Airflow DAG Authoring.\nThe purpose of the course is to prepare you as much as possible for the\nexam to put the odds in your favour. Not only you will be prepared for the\ncourse, but also you will learn how to create incredible data pipelines\nthanks to advanced Airflow features . The course is made up of video\nlectures, quizzes and additional studying resources.\n\nAt the end of the course you should feel confident enough to succeed for\nthe exam.\n\nKey Benefits\n\n+ Learn at your own pace and schedule\n+ Cost-effective exam preparation\n+ Free to access the course\n\na\n\x0c'
